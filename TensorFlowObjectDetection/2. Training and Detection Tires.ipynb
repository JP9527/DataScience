# %% [markdown]
# # 0. Setup Paths

# %%
import os

# %%
CUSTOM_MODEL_NAME = 'my_ssd_mobnet_tires' 
PRETRAINED_MODEL_NAME = 'ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8'
#PRETRAINED_MODEL_URL = 'http://download.tensorflow.org/models/object_detection/tf2/20200711/ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz'
PRETRAINED_MODEL_URL = 'http://download.tensorflow.org/models/object_detection/tf2/20200711/ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8.tar.gz'
TF_RECORD_SCRIPT_NAME = 'generate_tfrecord.py'
LABEL_MAP_NAME = 'label_map.pbtxt'

# %%
paths = {
    'WORKSPACE_PATH': os.path.join('Tensorflow', 'workspace'),
    'SCRIPTS_PATH': os.path.join('Tensorflow','scripts'),
    'APIMODEL_PATH': os.path.join('Tensorflow','models'),
    'ANNOTATION_PATH': os.path.join('Tensorflow', 'workspace','annotations'),
    'IMAGE_PATH': os.path.join('Tensorflow', 'workspace','tire-images'),
    'MODEL_PATH': os.path.join('Tensorflow', 'workspace','models'),
    'PRETRAINED_MODEL_PATH': os.path.join('Tensorflow', 'workspace','pre-trained-models'),
    'CHECKPOINT_PATH': os.path.join('Tensorflow', 'workspace','models',CUSTOM_MODEL_NAME), 
    'OUTPUT_PATH': os.path.join('Tensorflow', 'workspace','models',CUSTOM_MODEL_NAME, 'export'), 
    'TFJS_PATH':os.path.join('Tensorflow', 'workspace','models',CUSTOM_MODEL_NAME, 'tfjsexport'), 
    'TFLITE_PATH':os.path.join('Tensorflow', 'workspace','models',CUSTOM_MODEL_NAME, 'tfliteexport'), 
    'PROTOC_PATH':os.path.join('Tensorflow','protoc')
 }

# %%
files = {
    'PIPELINE_CONFIG':os.path.join('Tensorflow', 'workspace','models', CUSTOM_MODEL_NAME, 'pipeline.config'),
    'TF_RECORD_SCRIPT': os.path.join(paths['SCRIPTS_PATH'], TF_RECORD_SCRIPT_NAME), 
    'LABELMAP': os.path.join(paths['ANNOTATION_PATH'], LABEL_MAP_NAME)
}

# %%
files['LABELMAP']
# Out:
# 'Tensorflow\\workspace\\annotations\\label_map.pbtxt'

# %%
for path in paths.values():
    if not os.path.exists(path):
        if os.name == 'posix':
            # !mkdir -p {path}
        if os.name == 'nt':
            # !mkdir {path}

# %% [markdown]
# # 1. Download TF Models Pretrained Models from Tensorflow Model Zoo and Install TFOD

# %%
# https://www.tensorflow.org/install/source_windows

# %%
if os.name=='nt':
    # !pip install wget
    import wget
# Out:
# Requirement already satisfied: wget in c:\tfod\tfodcourse\tfod2\lib\site-packages (3.2)

# %%
if not os.path.exists(os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection')):
    # !git clone https://github.com/tensorflow/models {paths['APIMODEL_PATH']}

# %%
# Install Tensorflow Object Detection 
if os.name=='posix':  
    # !apt-get install protobuf-compiler
    # !cd Tensorflow/models/research && protoc object_detection/protos/*.proto --python_out=. && cp object_detection/packages/tf2/setup.py . && python -m pip install . 
    
if os.name=='nt':
    url="https://github.com/protocolbuffers/protobuf/releases/download/v3.15.6/protoc-3.15.6-win64.zip"
    wget.download(url)
    # !move protoc-3.15.6-win64.zip {paths['PROTOC_PATH']}
    # !cd {paths['PROTOC_PATH']} && tar -xf protoc-3.15.6-win64.zip
    os.environ['PATH'] += os.pathsep + os.path.abspath(os.path.join(paths['PROTOC_PATH'], 'bin'))   
    # !cd Tensorflow/models/research && protoc object_detection/protos/*.proto --python_out=. && copy object_detection\\packages\\tf2\\setup.py setup.py && python setup.py build && python setup.py install
    # !cd Tensorflow/models/research/slim && pip install -e .

# %%
VERIFICATION_SCRIPT = os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection', 'builders', 'model_builder_tf2_test.py')
# Verify Installation
# !python {VERIFICATION_SCRIPT}

# %%
# !pip install pyyaml

# %%
# !pip install tensorflow --upgrade

# %%
# !pip uninstall protobuf matplotlib -y
# !pip install protobuf matplotlib==3.2

# %%
import object_detection

# %%
# !pip list

# %%
if os.name =='posix':
    # !wget {PRETRAINED_MODEL_URL}
    # !mv {PRETRAINED_MODEL_NAME+'.tar.gz'} {paths['PRETRAINED_MODEL_PATH']}
    # !cd {paths['PRETRAINED_MODEL_PATH']} && tar -zxvf {PRETRAINED_MODEL_NAME+'.tar.gz'}
if os.name == 'nt':
    wget.download(PRETRAINED_MODEL_URL)
    # !move {PRETRAINED_MODEL_NAME+'.tar.gz'} {paths['PRETRAINED_MODEL_PATH']}
    # !cd {paths['PRETRAINED_MODEL_PATH']} && tar -zxvf {PRETRAINED_MODEL_NAME+'.tar.gz'}
# Out:
#  16% [...........                                                             ]  3366912 / 20518283
#  40% [............................                                            ]  8232960 / 20518283
#  64% [..............................................                          ] 13287424 / 20518283
#  74% [.....................................................                   ] 15368192 / 20518283
# 100% [........................................................................] 20518283 / 20518283
#         1 file(s) moved.
# x ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8/
# x ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8/checkpoint/
# x ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8/checkpoint/ckpt-0.data-00000-of-00001
# x ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8/checkpoint/checkpoint
# x ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8/checkpoint/ckpt-0.index
# x ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8/pipeline.config
# x ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8/saved_model/
# x ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8/saved_model/saved_model.pb
# x ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8/saved_model/variables/
# x ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8/saved_model/variables/variables.data-00000-of-00001
# x ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8/saved_model/variables/variables.index

# %% [markdown]
# # 2. Create Label Map

# %%
labels = [{'name':'tire', 'id':1}]

with open(files['LABELMAP'], 'w') as f:
    for label in labels:
        f.write('item { \n')
        f.write('\tname:\'{}\'\n'.format(label['name']))
        f.write('\tid:{}\n'.format(label['id']))
        f.write('}\n')

# %% [markdown]
# # 3. Create TF records

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\tfod\tfodcourse\tfod2\lib\site-packages (1.3.0)
# Requirement already satisfied: pytz>=2017.3 in c:\tfod\tfodcourse\tfod2\lib\site-packages (from pandas) (2021.1)
# Requirement already satisfied: numpy>=1.17.3 in c:\tfod\tfodcourse\tfod2\lib\site-packages (from pandas) (1.19.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\tfod\tfodcourse\tfod2\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\tfod\tfodcourse\tfod2\lib\site-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)

# %%
# OPTIONAL IF RUNNING ON COLAB
ARCHIVE_FILES = os.path.join(paths['IMAGE_PATH'], 'archive.tar.gz')
if os.path.exists(ARCHIVE_FILES):
  # !tar -zxvf {ARCHIVE_FILES}

# %%
if not os.path.exists(files['TF_RECORD_SCRIPT']):
    # !git clone https://github.com/nicknochnack/GenerateTFRecord {paths['SCRIPTS_PATH']}

# %%
# !python {files['TF_RECORD_SCRIPT']} -x {os.path.join(paths['IMAGE_PATH'], 'train')} -l {files['LABELMAP']} -o {os.path.join(paths['ANNOTATION_PATH'], 'train.record')} 
# !python {files['TF_RECORD_SCRIPT']} -x {os.path.join(paths['IMAGE_PATH'], 'test')} -l {files['LABELMAP']} -o {os.path.join(paths['ANNOTATION_PATH'], 'test.record')}
# Out:
# Successfully created the TFRecord file: Tensorflow\workspace\annotations\train.record
# Successfully created the TFRecord file: Tensorflow\workspace\annotations\test.record

# %%
paths['CHECKPOINT_PATH']
# Out:
# 'Tensorflow\\workspace\\models\\my_ssd_mobnet_tires'

# %% [markdown]
# # 4. Copy Model Config to Training Folder

# %%
if os.name =='posix':
    # !cp {os.path.join(paths['PRETRAINED_MODEL_PATH'], PRETRAINED_MODEL_NAME, 'pipeline.config')} {os.path.join(paths['CHECKPOINT_PATH'])}
if os.name == 'nt':
    # !copy {os.path.join(paths['PRETRAINED_MODEL_PATH'], PRETRAINED_MODEL_NAME, 'pipeline.config')} {os.path.join(paths['CHECKPOINT_PATH'])}
# Out:
#         1 file(s) copied.

# %%
paths['PRETRAINED_MODEL_PATH']
# Out:
# 'Tensorflow\\workspace\\pre-trained-models'

# %%
files['PIPELINE_CONFIG']
# Out:
# 'Tensorflow\\workspace\\models\\my_ssd_mobnet_tires\\pipeline.config'

# %% [markdown]
# # 5. Update Config For Transfer Learning

# %%
import tensorflow as tf
from object_detection.utils import config_util
from object_detection.protos import pipeline_pb2
from google.protobuf import text_format

# %%
config = config_util.get_configs_from_pipeline_file(files['PIPELINE_CONFIG'])

# %%
config
# Out:
# {'model': ssd {
#    num_classes: 90
#    image_resizer {
#      fixed_shape_resizer {
#        height: 640
#        width: 640
#      }
#    }
#    feature_extractor {
#      type: "ssd_mobilenet_v2_fpn_keras"
#      depth_multiplier: 1.0
#      min_depth: 16
#      conv_hyperparams {
#        regularizer {
#          l2_regularizer {
#            weight: 3.9999998989515007e-05
#          }
#        }
#        initializer {
#          random_normal_initializer {
#            mean: 0.0
#            stddev: 0.009999999776482582
#          }
#        }
#        activation: RELU_6
#        batch_norm {
#          decay: 0.996999979019165
#          scale: true
#          epsilon: 0.0010000000474974513
#        }
#      }
#      use_depthwise: true
#      override_base_feature_extractor_hyperparams: true
#      fpn {
#        min_level: 3
#        max_level: 7
#        additional_layer_depth: 128
#      }
#    }
#    box_coder {
#      faster_rcnn_box_coder {
#        y_scale: 10.0
#        x_scale: 10.0
#        height_scale: 5.0
#        width_scale: 5.0
#      }
#    }
#    matcher {
#      argmax_matcher {
#        matched_threshold: 0.5
#        unmatched_threshold: 0.5
#        ignore_thresholds: false
#        negatives_lower_than_unmatched: true
#        force_match_for_each_row: true
#        use_matmul_gather: true
#      }
#    }
#    similarity_calculator {
#      iou_similarity {
#      }
#    }
#    box_predictor {
#      weight_shared_convolutional_box_predictor {
#        conv_hyperparams {
#          regularizer {
#            l2_regularizer {
#              weight: 3.9999998989515007e-05
#            }
#          }
#          initializer {
#            random_normal_initializer {
#              mean: 0.0
#              stddev: 0.009999999776482582
#            }
#          }
#          activation: RELU_6
#          batch_norm {
#            decay: 0.996999979019165
#            scale: true
#            epsilon: 0.0010000000474974513
#          }
#        }
#        depth: 128
#        num_layers_before_predictor: 4
#        kernel_size: 3
#        class_prediction_bias_init: -4.599999904632568
#        share_prediction_tower: true
#        use_depthwise: true
#      }
#    }
#    anchor_generator {
#      multiscale_anchor_generator {
#        min_level: 3
#        max_level: 7
#        anchor_scale: 4.0
#        aspect_ratios: 1.0
#        aspect_ratios: 2.0
#        aspect_ratios: 0.5
#        scales_per_octave: 2
#      }
#    }
#    post_processing {
#      batch_non_max_suppression {
#        score_threshold: 9.99999993922529e-09
#        iou_threshold: 0.6000000238418579
#        max_detections_per_class: 100
#        max_total_detections: 100
#        use_static_shapes: false
#      }
#      score_converter: SIGMOID
#    }
#    normalize_loss_by_num_matches: true
#    loss {
#      localization_loss {
#        weighted_smooth_l1 {
#        }
#      }
#      classification_loss {
#        weighted_sigmoid_focal {
#          gamma: 2.0
#          alpha: 0.25
#        }
#      }
#      classification_weight: 1.0
#      localization_weight: 1.0
#    }
#    encode_background_as_zeros: true
#    normalize_loc_loss_by_codesize: true
#    inplace_batchnorm_update: true
#    freeze_batchnorm: false
#  },
#  'train_config': batch_size: 128
#  data_augmentation_options {
#    random_horizontal_flip {
#    }
#  }
#  data_augmentation_options {
#    random_crop_image {
#      min_object_covered: 0.0
#      min_aspect_ratio: 0.75
#      max_aspect_ratio: 3.0
#      min_area: 0.75
#      max_area: 1.0
#      overlap_thresh: 0.0
#    }
#  }
#  sync_replicas: true
#  optimizer {
#    momentum_optimizer {
#      learning_rate {
#        cosine_decay_learning_rate {
#          learning_rate_base: 0.07999999821186066
#          total_steps: 50000
#          warmup_learning_rate: 0.026666000485420227
#          warmup_steps: 1000
#        }
#      }
#      momentum_optimizer_value: 0.8999999761581421
#    }
#    use_moving_average: false
#  }
#  fine_tune_checkpoint: "PATH_TO_BE_CONFIGURED"
#  num_steps: 50000
#  startup_delay_steps: 0.0
#  replicas_to_aggregate: 8
#  max_number_of_boxes: 100
#  unpad_groundtruth_tensors: false
#  fine_tune_checkpoint_type: "classification"
#  fine_tune_checkpoint_version: V2,
#  'train_input_config': label_map_path: "PATH_TO_BE_CONFIGURED"
#  tf_record_input_reader {
#    input_path: "PATH_TO_BE_CONFIGURED"
#  },
#  'eval_config': metrics_set: "coco_detection_metrics"
#  use_moving_averages: false,
#  'eval_input_configs': [label_map_path: "PATH_TO_BE_CONFIGURED"
#  shuffle: false
#  num_epochs: 1
#  tf_record_input_reader {
#    input_path: "PATH_TO_BE_CONFIGURED"
#  }
#  ],
#  'eval_input_config': label_map_path: "PATH_TO_BE_CONFIGURED"
#  shuffle: false
#  num_epochs: 1
#  tf_record_input_reader {
#    input_path: "PATH_TO_BE_CONFIGURED"
#  }}

# %%
pipeline_config = pipeline_pb2.TrainEvalPipelineConfig()
with tf.io.gfile.GFile(files['PIPELINE_CONFIG'], "r") as f:                                                                                                                                                                                                                     
    proto_str = f.read()                                                                                                                                                                                                                                          
    text_format.Merge(proto_str, pipeline_config)

# %%
proto_str
# Out:
# 'model {\n  ssd {\n    num_classes: 90\n    image_resizer {\n      fixed_shape_resizer {\n        height: 640\n        width: 640\n      }\n    }\n    feature_extractor {\n      type: "ssd_mobilenet_v2_fpn_keras"\n      depth_multiplier: 1.0\n      min_depth: 16\n      conv_hyperparams {\n        regularizer {\n          l2_regularizer {\n            weight: 3.9999998989515007e-05\n          }\n        }\n        initializer {\n          random_normal_initializer {\n            mean: 0.0\n            stddev: 0.009999999776482582\n          }\n        }\n        activation: RELU_6\n        batch_norm {\n          decay: 0.996999979019165\n          scale: true\n          epsilon: 0.0010000000474974513\n        }\n      }\n      use_depthwise: true\n      override_base_feature_extractor_hyperparams: true\n      fpn {\n        min_level: 3\n        max_level: 7\n        additional_layer_depth: 128\n      }\n    }\n    box_coder {\n      faster_rcnn_box_coder {\n        y_scale: 10.0\n        x_scale: 10.0\n        height_scale: 5.0\n        width_scale: 5.0\n      }\n    }\n    matcher {\n      argmax_matcher {\n        matched_threshold: 0.5\n        unmatched_threshold: 0.5\n        ignore_thresholds: false\n        negatives_lower_than_unmatched: true\n        force_match_for_each_row: true\n        use_matmul_gather: true\n      }\n    }\n    similarity_calculator {\n      iou_similarity {\n      }\n    }\n    box_predictor {\n      weight_shared_convolutional_box_predictor {\n        conv_hyperparams {\n          regularizer {\n            l2_regularizer {\n              weight: 3.9999998989515007e-05\n            }\n          }\n          initializer {\n            random_normal_initializer {\n              mean: 0.0\n              stddev: 0.009999999776482582\n            }\n          }\n          activation: RELU_6\n          batch_norm {\n            decay: 0.996999979019165\n            scale: true\n            epsilon: 0.0010000000474974513\n          }\n        }\n        depth: 128\n        num_layers_before_predictor: 4\n        kernel_size: 3\n        class_prediction_bias_init: -4.599999904632568\n        share_prediction_tower: true\n        use_depthwise: true\n      }\n    }\n    anchor_generator {\n      multiscale_anchor_generator {\n        min_level: 3\n        max_level: 7\n        anchor_scale: 4.0\n        aspect_ratios: 1.0\n        aspect_ratios: 2.0\n        aspect_ratios: 0.5\n        scales_per_octave: 2\n      }\n    }\n    post_processing {\n      batch_non_max_suppression {\n        score_threshold: 9.99999993922529e-09\n        iou_threshold: 0.6000000238418579\n        max_detections_per_class: 100\n        max_total_detections: 100\n        use_static_shapes: false\n      }\n      score_converter: SIGMOID\n    }\n    normalize_loss_by_num_matches: true\n    loss {\n      localization_loss {\n        weighted_smooth_l1 {\n        }\n      }\n      classification_loss {\n        weighted_sigmoid_focal {\n          gamma: 2.0\n          alpha: 0.25\n        }\n      }\n      classification_weight: 1.0\n      localization_weight: 1.0\n    }\n    encode_background_as_zeros: true\n    normalize_loc_loss_by_codesize: true\n    inplace_batchnorm_update: true\n    freeze_batchnorm: false\n  }\n}\ntrain_config {\n  batch_size: 128\n  data_augmentation_options {\n    random_horizontal_flip {\n    }\n  }\n  data_augmentation_options {\n    random_crop_image {\n      min_object_covered: 0.0\n      min_aspect_ratio: 0.75\n      max_aspect_ratio: 3.0\n      min_area: 0.75\n      max_area: 1.0\n      overlap_thresh: 0.0\n    }\n  }\n  sync_replicas: true\n  optimizer {\n    momentum_optimizer {\n      learning_rate {\n        cosine_decay_learning_rate {\n          learning_rate_base: 0.07999999821186066\n          total_steps: 50000\n          warmup_learning_rate: 0.026666000485420227\n          warmup_steps: 1000\n        }\n      }\n      momentum_optimizer_value: 0.8999999761581421\n    }\n    use_moving ...

# %%
pipeline_config.model.ssd.num_classes = len(labels)
pipeline_config.train_config.batch_size = 8
pipeline_config.train_config.fine_tune_checkpoint = os.path.join(paths['PRETRAINED_MODEL_PATH'], PRETRAINED_MODEL_NAME, 'checkpoint', 'ckpt-0')
pipeline_config.train_config.fine_tune_checkpoint_type = "detection"
pipeline_config.train_input_reader.label_map_path= files['LABELMAP']
pipeline_config.train_input_reader.tf_record_input_reader.input_path[:] = [os.path.join(paths['ANNOTATION_PATH'], 'train.record')]
pipeline_config.eval_input_reader[0].label_map_path = files['LABELMAP']
pipeline_config.eval_input_reader[0].tf_record_input_reader.input_path[:] = [os.path.join(paths['ANNOTATION_PATH'], 'test.record')]

# %%
config_text = text_format.MessageToString(pipeline_config)                                                                                                                                                                                                        
with tf.io.gfile.GFile(files['PIPELINE_CONFIG'], "wb") as f:                                                                                                                                                                                                                     
    f.write(config_text)

# %% [markdown]
# # 6. Train the model

# %%
paths['APIMODEL_PATH']
# Out:
# 'Tensorflow\\models'

# %%
TRAINING_SCRIPT = os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection', 'model_main_tf2.py')

# %%
command = "python {} --model_dir={} --pipeline_config_path={} --num_train_steps=2000".format(TRAINING_SCRIPT, paths['CHECKPOINT_PATH'],files['PIPELINE_CONFIG'])

# %%
print(command)
# Out:
# python Tensorflow\models\research\object_detection\model_main_tf2.py --model_dir=Tensorflow\workspace\models\my_ssd_mobnet_tires --pipeline_config_path=Tensorflow\workspace\models\my_ssd_mobnet_tires\pipeline.config --num_train_steps=2000

# %%
# !{command}
# Out:
# 2021-07-25 14:20:52.068635: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library cudart64_110.dll
# 2021-07-25 14:20:55.621609: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library nvcuda.dll
# 2021-07-25 14:20:55.649933: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: Quadro P2000 computeCapability: 6.1
# coreClock: 1.607GHz coreCount: 6 deviceMemorySize: 4.00GiB deviceMemoryBandwidth: 89.53GiB/s
# 2021-07-25 14:20:55.650267: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library cudart64_110.dll
# 2021-07-25 14:20:55.659750: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library cublas64_11.dll
# 2021-07-25 14:20:55.659924: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library cublasLt64_11.dll
# 2021-07-25 14:20:55.663639: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library cufft64_10.dll
# 2021-07-25 14:20:55.665364: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library curand64_10.dll
# 2021-07-25 14:20:55.673470: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library cusolver64_11.dll
# 2021-07-25 14:20:55.676422: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library cusparse64_11.dll
# 2021-07-25 14:20:55.677520: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library cudnn64_8.dll
# 2021-07-25 14:20:55.677732: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0
# 2021-07-25 14:20:55.678068: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX AVX2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-07-25 14:20:55.679296: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: Quadro P2000 computeCapability: 6.1
# coreClock: 1.607GHz coreCount: 6 deviceMemorySize: 4.00GiB deviceMemoryBandwidth: 89.53GiB/s
# 2021-07-25 14:20:55.679680: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0
# 2021-07-25 14:20:56.184296: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-07-25 14:20:56.184552: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0
# 2021-07-25 14:20:56.184664: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N
# 2021-07-25 14:20:56.184902: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 2772 MB memory) -> physical GPU (device: 0, name: Quadro P2000, pci bus id: 0000:01:00.0, compute capability: 6.1)
# WARNING:tensorflow:Collective ops is not configured at program startup. Some performance features may not be enabled.
# W0725 14:20:56.187256 19588 mirrored_strategy.py:379] Collective ops is not configured at program startup. Some performance features may not be enabled.
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# I0725 14:20:56.311681 19588 mirrored_strategy.py:369] Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# INFO:tensorflow:Maybe overwriting train_steps: 2000
# I0725 14:20:56.315716 19588 config_util.py:552] Maybe overwriting train_steps: 2000
# INFO:tensorflow:Maybe overwriting use_bfloat16: False
# I0725 14:20:56.315716 19588 config_util.py:552] Maybe overwriting use_bfloat16: False
# WARNING:tensorflow:From C:\TFOD\TFODCourse\tfod2\lib\site-packages\object_detection-0.1-py3.8.egg\object_detection\model_lib_v2.py:557: StrategyBase.experimental_distribute_datasets_from_function (from tensorflow.python.distribute.distribute_lib) is deprecated and will be removed in a future version.
# Instructions for updating:
# rename to distribute_datasets_from_function
# W0725 14:20:56.332690 19588 deprecation.py:330] From C:\TFOD\TFODCourse\tfod2\lib\site-packages\object_detection-0.1-py3.8.egg\object_detection\model_lib_v2.py:557: StrategyBase.experimental_distribute_datasets_from_function (from tensorflow.python.distribute.distribute_lib) is deprecated and will be removed in a future version.
# Instructions for updating:
# rename to distribute_datasets_from_function
# INFO:tensorflow:Reading unweighted datasets: ['Tensorflow\\workspace\\annotations\\train.record']
# I0725 14:20:56.336683 19588 dataset_builder.py:163] Reading unweighted datasets: ['Tensorflow\\workspace\\annotations\\train.record']
# INFO:tensorflow:Reading record datasets for input file: ['Tensorflow\\workspace\\annotations\\train.record']
# I0725 14:20:56.336683 19588 dataset_builder.py:80] Reading record datasets for input file: ['Tensorflow\\workspace\\annotations\\train.record']
# INFO:tensorflow:Number of filenames to read: 1
# I0725 14:20:56.336683 19588 dataset_builder.py:81] Number of filenames to read: 1
# WARNING:tensorflow:num_readers has been reduced to 1 to match input file shards.
# W0725 14:20:56.336683 19588 dataset_builder.py:87] num_readers has been reduced to 1 to match input file shards.
# WARNING:tensorflow:From C:\TFOD\TFODCourse\tfod2\lib\site-packages\object_detection-0.1-py3.8.egg\object_detection\builders\dataset_builder.py:101: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.experimental_deterministic`.
# W0725 14:20:56.337715 19588 deprecation.py:330] From C:\TFOD\TFODCourse\tfod2\lib\site-packages\object_detection-0.1-py3.8.egg\object_detection\builders\dataset_builder.py:101: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.experimental_deterministic`.
# WARNING:tensorflow:From C:\TFOD\TFODCourse\tfod2\lib\site-packages\object_detection-0.1-py3.8.egg\object_detection\builders\dataset_builder.py:236: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# W0725 14:20:56.355715 19588 deprecation.py:330] From C:\TFOD\TFODCourse\tfod2\lib\site-packages\object_detection-0.1-py3.8.egg\object_detection\builders\dataset_builder.py:236: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# WARNING:tensorflow:From C:\TFOD\TFODCourse\tfod2\lib\site-packages\tensorflow\python\util\dispatch.py:206: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# W0725 14:21:01.443833 19588 deprecation.py:330] From C:\TFOD\TFODCourse\tfod2\lib\site-packages\tensorflow\python\util\dispatch.py:206: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# WARNING:tensorflow:From C:\TFOD\TFODCourse\tfod2\lib\site-packages\tensorflow\python\util\dispatch.py:206: sample_distorted_bounding_box (from tensorflow.python.ops.image_ops_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# `seed2` arg is deprecated.Use sample_distorted_bounding_box_v2 instead.
# W0725 14:21:03.789562 19588 deprecation.py:330] From C:\TFOD\TFODCourse\tfod2\lib\site-packages\tensorflow\python\util\dispatch.py:206: sample_distorted_bounding_box (from tensorflow.python.ops.image_ops_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# `seed2` arg is deprecated.Use sample_distorted_bounding_box_v2 instead.
# WARNING:tensorflow:From C:\TFOD\TFODCourse\tfod2\lib\site-packages\tensorflow\python\autograph\impl\api.py:464: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W0725 14:21:05.133241 19588 deprecation.py:330] From C:\TFOD\TFODCourse\tfod2\lib\site-packages\tensorflow\python\autograph\impl\api.py:464: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# 2021-07-25 14:21:06.890062: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2021-07-25 14:21:22.015542: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library cudnn64_8.dll
# 2021-07-25 14:21:22.350087: I tensorflow/stream_executor/cuda/cuda_dnn.cc:359] Loaded cuDNN version 8100
# 2021-07-25 14:21:22.727646: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library cublas64_11.dll
# 2021-07-25 14:21:23.012499: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library cublasLt64_11.dll
# 2021-07-25 14:21:23.499262: W tensorflow/core/common_runtime/bfc_allocator.cc:271] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.28GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2021-07-25 14:21:24.284216: W tensorflow/core/common_runtime/bfc_allocator.cc:271] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.57GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2021-07-25 14:21:24.309031: W tensorflow/core/common_runtime/bfc_allocator.cc:271] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.36GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# C:\TFOD\TFODCourse\tfod2\lib\site-packages\tensorflow\python\keras\backend.py:435: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn('`tf.keras.backend.set_learning_phase` is deprecated and '
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0725 14:21:25.660748 19588 cross_device_ops.py:619] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0725 14:21:25.660748 19588 cross_device_ops.py:619] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0725 14:21:25.662747 19588 cross_device_ops.py:619] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0725 14:21:25.663781 19588 cross_device_ops.py:619] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0725 14:21:25.665782 19588 cross_device_ops.py:619] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0725 14:21:25.666781 19588 cross_device_ops.py:619] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0725 14:21:25.668747 19588 cross_device_ops.py:619] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0725 14:21:25.669746 19588 cross_device_ops.py:619] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0725 14:21:25.671746 19588 cross_device_ops.py:619] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0725 14:21:25.672783 19588 cross_device_ops.py:619] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# WARNING:tensorflow:From C:\TFOD\TFODCourse\tfod2\lib\site-packages\tensorflow\python\util\deprecation.py:602: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead
# W0725 14:21:26.232781  9816 deprecation.py:528] From C:\TFOD\TFODCourse\tfod2\lib\site-packages\tensorflow\python\util\deprecation.py:602: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead
# 2021-07-25 14:21:54.454674: W tensorflow/core/common_runtime/bfc_allocator.cc:271] Allocator (GPU_0_bfc) ran out of memory trying to allocate 213.34MiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2021-07-25 14:21:54.473080: W tensorflow/core/common_runtime/bfc_allocator.cc:271] Allocator (GPU_0_bfc) ran out of memory trying to allocate 410.69MiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2021-07-25 14:21:54.473960: W tensorflow/core/common_runtime/bfc_allocator.cc:271] Allocator (GPU_0_bfc) ran out of memory trying to allocate 223.19MiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2021-07-25 14:21:54.493843: W tensorflow/core/common_runtime/bfc_allocator.cc:271] Allocator (GPU_0_bfc) ran out of memory trying to allocate 430.39MiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2021-07-25 14:21:54.602376: W tensorflow/core/common_runtime/bfc_allocator.cc:271] Allocator (GPU_0_bfc) ran out of memory trying to allocate 550.25MiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2021-07-25 14:21:54.643634: W tensorflow/core/common_runtime/bfc_allocator.cc:271] Allocator (GPU_0_bfc) ran out of memory trying to allocate 577.06MiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2021-07-25 14:21:54.687074: W tensorflow/core/common_runtime/bfc_allocator.cc:271] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.07GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2021-07-25 14:23:24.321239: W tensorflow/core/common_runtime/bfc_allocator.cc:456] Allocator (GPU_0_bfc) ran out of memory trying to allocate 25.00MiB (rounded to 26214400)requested by op while/body/_1/WeightSharedConvolutionalBoxPredictor/PredictionTower/conv2d_3/separable_conv2d
# If the cause is memory fragmentation maybe the environment variable 'TF_GPU_ALLOCATOR=cuda_malloc_async' will improve the situation.
# Current allocation summary follows.
# Current allocation summary follows.
# 2021-07-25 14:23:24.322345: I tensorflow/core/common_runtime/bfc_allocator.cc:991] BFCAllocator dump for GPU_0_bfc
# 2021-07-25 14:23:24.322516: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (256): 	Total Chunks: 241, Chunks in use: 239. 60.3KiB allocated for chunks. 59.8KiB in use in bin. 16.9KiB client-requested in use in bin.
# 2021-07-25 14:23:24.322837: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (512): 	Total Chunks: 321, Chunks in use: 319. 185.3KiB allocated for chunks. 184.3KiB in use in bin. 166.6KiB client-requested in use in bin.
# 2021-07-25 14:23:24.323212: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (1024): 	Total Chunks: 89, Chunks in use: 89. 119.3KiB allocated for chunks. 119.3KiB in use in bin. 109.5KiB client-requested in use in bin.
# 2021-07-25 14:23:24.323548: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (2048): 	Total Chunks: 121, Chunks in use: 121. 353.5KiB allocated for chunks. 353.5KiB in use in bin. 338.4KiB client-requested in use in bin.
# 2021-07-25 14:23:24.323914: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (4096): 	Total Chunks: 71, Chunks in use: 71. 358.3KiB allocated for chunks. 358.3KiB in use in bin. 337.0KiB client-requested in use in bin.
# 2021-07-25 14:23:24.324234: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (8192): 	Total Chunks: 42, Chunks in use: 41. 503.3KiB allocated for chunks. 495.3KiB in use in bin. 452.9KiB client-requested in use in bin.
# 2021-07-25 14:23:24.324578: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (16384): 	Total Chunks: 44, Chunks in use: 43. 932.5KiB allocated for chunks. 913.8KiB in use in bin. 862.3KiB client-requested in use in bin.
# 2021-07-25 14:23:24.324840: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (32768): 	Total Chunks: 23, Chunks in use: 23. 968.0KiB allocated for chunks. 968.0KiB in use in bin. 875.3KiB client-requested in use in bin.
# 2021-07-25 14:23:24.325059: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (65536): 	Total Chunks: 54, Chunks in use: 54. 4.72MiB allocated for chunks. 4.72MiB in use in bin. 4.48MiB client-requested in use in bin.
# 2021-07-25 14:23:24.325459: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (131072): 	Total Chunks: 38, Chunks in use: 37. 7.34MiB allocated for chunks. 7.18MiB in use in bin. 7.05MiB client-requested in use in bin.
# 2021-07-25 14:23:24.325726: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (262144): 	Total Chunks: 19, Chunks in use: 18. 7.21MiB allocated for chunks. 6.79MiB in use in bin. 6.17MiB client-requested in use in bin.
# 2021-07-25 14:23:24.325964: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (524288): 	Total Chunks: 34, Chunks in use: 32. 21.00MiB allocated for chunks. 19.67MiB in use in bin. 19.14MiB client-requested in use in bin.
# 2021-07-25 14:23:24.326255: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (1048576): 	Total Chunks: 21, Chunks in use: 20. 30.29MiB allocated for chunks. 29.12MiB in use in bin. 28.90MiB client-requested in use in bin.
# 2021-07-25 14:23:24.326555: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (2097152): 	Total Chunks: 8, Chunks in use: 7. 24.21MiB allocated for chunks. 21.08MiB in use in bin. 18.74MiB client-requested in use in bin.
# 2021-07-25 14:23:24.326825: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (4194304): 	Total Chunks: 27, Chunks in use: 25. 165.78MiB allocated for chunks. 153.28MiB in use in bin. 147.62MiB client-requested in use in bin.
# 2021-07-25 14:23:24.327060: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (8388608): 	Total Chunks: 13, Chunks in use: 12. 151.92MiB allocated for chunks. 139.42MiB in use in bin. 128.12MiB client-requested in use in bin.
# 2021-07-25 14:23:24.327443: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (16777216): 	Total Chunks: 25, Chunks in use: 25. 621.74MiB allocated for chunks. 621.74MiB in use in bin. 610.12MiB client-requested in use in bin.
# 2021-07-25 14:23:24.327687: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (33554432): 	Total Chunks: 8, Chunks in use: 8. 334.28MiB allocated for chunks. 334.28MiB in use in bin. 300.00MiB client-requested in use in bin.
# 2021-07-25 14:23:24.327900: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (67108864): 	Total Chunks: 3, Chunks in use: 3. 309.89MiB allocated for chunks. 309.89MiB in use in bin. 287.50MiB client-requested in use in bin.
# 2021-07-25 14:23:24.328195: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (134217728): 	Total Chunks: 4, Chunks in use: 4. 677.16MiB allocated for chunks. 677.16MiB in use in bin. 400.00MiB client-requested in use in bin.
# 2021-07-25 14:23:24.328490: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (268435456): 	Total Chunks: 1, Chunks in use: 1. 413.49MiB allocated for chunks. 413.49MiB in use in bin. 300.00MiB client-requested in use in bin.
# 2021-07-25 14:23:24.328650: I tensorflow/core/common_runtime/bfc_allocator.cc:1014] Bin for 25.00MiB was 16.00MiB, Chunk State:
# 2021-07-25 14:23:24.328827: I tensorflow/core/common_runtime/bfc_allocator.cc:1027] Next region of size 2907098112
# 2021-07-25 14:23:24.340269: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at c02800000 of size 1280 by op ScratchBuffer action_count 1 step 0 next 1
# 2021-07-25 14:23:24.340444: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at c02800500 of size 256 by op AssignVariableOp action_count 2 step 0 next 2
# 2021-07-25 14:23:24.340640: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at c02800600 of size 256 by op AssignVariableOp action_count 3 step 0 next 3
# 2021-07-25 14:23:24.340942: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at c02800700 of size 256 by op Mul action_count 76 step 0 next 4
# 2021-07-25 14:23:24.341120: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at c02800800 of size 368640 by op AssignVariableOp action_count 4717 step 0 next 452
# 2021-07-25 14:23:24.341305: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at c0285a800 of size 256 by op Fill action_count 4971 step 0 next 494
# 2021-07-25 14:23:24.341590: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at c0285a900 of size 256 by op Fill action_count 4972 step 0 next 458
# 2021-07-25 14:23:24.341829: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at c0285aa00 of size 98304 by op Fill action_count 4973 step 0 next 495
# 2021-07-25 14:23:24.342061: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at c02872a00 of size 1536 by op Fill action_count 4974 step 0 next 591
# 2021-07-25 14:23:24.342216: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at c02873000 of size 1536 by op Fill action_count 4975 step 0 next 604
# 2021-07-25 14:23:24.342431: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at c02873600 of size 13824 by op Fill action_count 4976 step 0 next 595
# 2021-07-25 14:23:24.342585: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at c02876c00 of size 1536 by op Fill action_count 4977 step 0 next 587
# 2021-07-25 14:23:24.342754: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at c02877200 of size 1536 by op Fill action_count 4978 step 0 next 583
# 2021-07-25 14:23:24.342901: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at c
I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at c0312a300 of size 256 by op Cast action_count 5072 step 0 next 645
# 2021-07-25 14:23:24.359891: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at c0312a400 of size 256 by op Cast action_count 5075 step 0 next 646
# 2021-07-25 14:23:24.359973: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at c0312a500 of size 256 by op Cast action_count 5078 step 0 next 647
# 2021-07-25 14:23:24.360179: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at c0312a600 of size 256 by op Cast action_count 5081 step 0 next 648
# 2021-07-25 14:23:24.360375: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at c0312a700 of size 256 by op Cast action_count 5084 step 0 next 649
# 2021-07-25 14:23:24.360476: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at c0312a800 of size 256 by op Cast action_count 5087 step 0 next 650
# 2021-07-25 14:23:24.360672: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at c0312a900 of size 256 by op Cast action_count 5090 step 0 next 651
# 2021-07-25 14:23:24.360851: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at c0312aa00 of size 256 by op Cast action_count 5093 step 0 next 652
# 2021-07-25 14:23:24.361035: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at c0312ab00 of size 256 by op Cast action_count 5096 step 0 next 653
# 2021-07-25 14:23:24.361122: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at c0312ac00 of size 256 by op Cast action_count 5099 step 0 next 654
# 2021-07-25 14:23:24.361339: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at c0312ad00 of size 256 by op Cast action_count 5102 step 0 next 655
# 2021-07-25 14:23:24.361547: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at c0312ae00 of size 256 by op Cast action_count 5105 step 0 next 656
# 2021-07-25 14:23:24.361712: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at c0312af00 of size 256 by op Cast action_count 5108 step 0 next 657
# 2021-07-25 14:23:24.361870: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at c0312b000 of size 256 by op Cast action_count 5111 step 0 next 658
# 2021-07-25 14:23:24.361980: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at c0312b100 of size 256 by op Cast action_count 5114 step 0 next 659
# 2021-07-25 14:23:24.362062: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at c0312b200 of size 4608 by op gradient_tape/WeightSharedConvolutionalBoxPredictor/PredictionTower/conv2d_1/depthwise_kernel/Regularizer/Mul action_count 5117 step 0 next 660
# 2021-07-25 14:23:24.362458: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at c0312c400 of size 6912 by op gradient_tape/block_4_depthwise/depthwise_kernel/Regularizer/Mul action_count 5118 step 0 next 661
# 2021-07-25 14:23:24.362688: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at c0312df00 of size 24576 by op gradient_tape/block_4_project/kernel/Regularizer/Mul action_count 5119 step 0 next 662
# 2021-07-25 14:23:24.362902: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at c03133f00 of size 24576 by op gradient_tape/block_5_expand/kernel/Regularizer/Mul action_count 5120 step 0 next 663
# 2021-07-25 14:23:24.363110: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at c03139f00 of size 49152 by op gradient_tape/block_6_project/kernel/Regularizer/Mul action_count 5121 step 0 next 664
# 2021-07-25 14:23:24.363374: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at c03145f00 of size 98304 by op gradient_tape/block_7_expand/kernel/Regularizer/Mul action_count 5122 step 0 next 665
# 2021-07-25 14:23:24.363622: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at c0315df00 of size 13824 by op gradient_tape/block_7_depthwise/depthwise_kernel/Regularizer/Mul action_count 5123 step 0 next 666
# 2021-07-25 14:23:24.363822: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at c03161500 of size 98304 by op gradient_tape/block_7_project/kernel/Regularizer/Mul action_count 5124 step 0 next 667
# 2021-07-25 14:23:24.364015: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at c03179500 of size 20736 by op gradient_tape/block_11_depthwise/depthwise_kernel/Regularizer/Mul action_count 5125 step 0 next 668
# 2021-07-25 14:23:24.364212: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at c0317e600 of size 34560 by op gradient_tape/block_14_depthwise/depthwise_kernel/Regularizer/Mul action_count 5126 step 0 next 669
# 2021-07-25 14:23:24.364499: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at c03186d00 of size 256 by op gradient_tape/WeightSharedConvolutionalBoxPredictor/PredictionTower/conv2d_1/depthwise_kernel/Regularizer/Reshape action_count 5127 step 0 next 670
# 2021-07-25 14:23:24.364747: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at c03186e00 of size 49152 by op gradient_tape/ssd_mobile_net_v2fpn_keras_feature_extractor/FeatureMaps/top_down/projection_2/kernel/Regularizer/Mul action_count 5128 step 0 next 671
# 2021-07-25 14:23:24.365085: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at c03192e00 of size 16384 by op gradient_tape/ssd_mobile_net_v2fpn_keras_feature_extractor/FeatureMaps/top_down/projection_1/kernel/Regularizer/Mul action_count 5129 step 0 next 672
# 2021-07-25 14:23:24.365356: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at c03196e00 of size 3584 by op gradient_tape/Conv1/kernel/Regularizer/Mul action_count 5130 step 0 next 673
# 2021-07-25 14:23:24.365599: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at c03197c00 of size 1280 by op gradient_tape/expanded_conv_depthwise/depthwise_kernel/Regularizer/Mul action_count 5131 step 0 next 674
# 2021-07-25 14:23:24.365855: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at c03198100 of size 2048 by op gradient_tape/expanded_conv_project/kernel/Regularizer/Mul action_count 5132 step 0 next 675
# 2021-07-25 14:23:24.366120: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at c03198900 of size 6144 by op gradient_tape/block_1_expand/kernel/Regularizer/Mul action_count 5133 step 0 next 676
# 2021-07-25 14:23:24.366376: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at c0319a100 of size 3584 by op gradient_tape/block_1_depthwise/depthwise_kernel/Regularizer/Mul action_count 5134 step 0 next 677
# 2021-07-25 14:23:24.366538: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at c0319af00 of size 9216 by op gradient_tape/block_1_project/kernel/Regularizer/Mul action_count 5135 step 0 next 678
# 2021-07-25 14:23:24.366782: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at c0319d300 of size 13824 by op gradient_tape/block_2_expand/kernel/Regularizer/Mul action_count 5136 step 0 next 679
# 2021-07-25 14:23:24.366970: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at c031a0900 of size 5376 by op gradient_tape/block_2_depthwise/depthwise_kernel/Regularizer/Mul action_count 5137 step 0 next 680
# 2021-07-25 14:23:24.367193: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at c031a1e00 of size 13824 by op gradient_tape/block_2_project/kernel/Regularizer/Mul action_count 5138 step 0 next 681
# 2021-07-25 14:23:24.367542: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at c031a5400 of size 18432 by op gradient_tape/block_3_project/kernel/Regularizer/Mul action_count 5139 step 0 next 682
# 2021-07-25 14:23:24.367763: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at c031a9c00 of size 256 by op SGD/Greater/y action_count 5140 step 0 next 683
# 2021-07-25 14:23:24.367933: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at c031a9d00 of size 256 by op SGD/Less/y action_count 5141 step 0 next 684
# ...
# 2021-07-25 14:23:24.435007: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at c04def600 of size 9472 by op while/body/_1/gradient_tape/block_6_depthwise/depthwise_kernel/Regularizer/Mul_1 action_count 206400 step 17194364464801385511 next 246
# 2021-07-25 14:23:24.435296: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at c04df1b00 of size 3840 by op AssignVariableOp action_count 4741 step 0 next 247
# 2021-07-25 14:23:24.435470: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at c04df2a00 of size 1536 by op while/body/_1/ssd_mobile_net_v2fpn_keras_feature_extractor/model/block_7_depthwise_BN/FusedBatchNormV3 action_count 207547 step 17194364464801385511 next 1029
# 2021-07-25 14:23:24.435743: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at c04df3000 of size 2304 by op while/body/_1/ssd_mobile_net_v2fpn_keras_feature_extractor/model/block_12_expand_BN/FusedBatchNormV3 action_count 207724 step 17194364464801385511 next 248
# 2021-07-25 14:23:24.436023: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at c04df3900 of size 4608 by op AssignVariableOp action_count 4767 step 0 next 251
# 2021-07-25 14:23:24.436186: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at c04df4b00 of size 768 by op AssignVariableOp action_count 4751 step 0 next 252
# 2021-07-25 14:23:24.436371: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at c04df4e00 of size 768 by op while/body/_1/ssd_mobile_net_v2fpn_keras_feature_extractor/model/block_2_expand_BN/FusedBatchNormV3 action_count 207358 step 17194364464801385511 next 253
# 2021-07-25 14:23:24.436683: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at c04df5100 of size 768 by op AssignVariableOp action_count 4757 step 0 next 254
# 2021-07-25 14:23:24.436846: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at c04df5400 of size 3840 by op while/body/_1/ssd_mobile_net_v2fpn_keras_feature_extractor/model/block_14_expand_BN/FusedBatchNormV3 action_count 207800 step 17194364464801385511 next 256
# 2021-07-25 14:23:24.437159: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at c04df6300 of size 6912 by op AssignVariableOp action_count 4769 step 0 next 128
# 2021-07-25 14:23:24.437345: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at c04df7e00 of size 13824 by op AssignVariableOp action_count 4575 step 0 next 161
# 2021-07-25 14:23:24.437531: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at c04dfb400 of size 13824 by op AssignVariableOp action_count 4607 step 0 next 176
# 2021-07-25 14:23:24.437714: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at c04dfea00 of size 21504 by op AssignVariableOp action_count 4637 step 0 next 129
# 2021-07-25 14:23:24.437843: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at c04e03e00 of size 512 by op while/body/_1/ssd_mobile_net_v2fpn_keras_feature_extractor/model/block_1_depthwise_BN/FusedBatchNormV3 action_count 207331 step 17194364464801385511 next 205
# 2021-07-25 14:23:24.438230: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at c04e04000 of size 512 by op AssignVariableOp action_count 4659 step 0 next 206
# 2021-07-25 14:23:24.438374: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at c04e04200 of size 3328 by op SameWorkerRecvDone action_count 206207 step 0 next 210
# 2021-07-25 14:23:24.438472: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at c04e04f00 of size 2304 by op AssignVariableOp action_count 4669 step 0 next 211
# 2021-07-25 14:23:24.438569: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at c04e05800 of size 1536 by op while/body/_1/ssd_mobile_net_v2fpn_keras_feature_extractor/model/block_7_expand_BN/FusedBatchNormV3 action_count 207538 step 17194364464801385511 next 916
# 2021-07-25 14:23:24.438926: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at c04e05e00 of size 256 by op SameWorkerRecvDone action_count 206237 step 0 next 902
# 2021-07-25 14:23:24.439095: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at c04e05f00 of size 512 by op while/body/_1/ssd_mobile_net_v2fpn_keras_feature_extractor/model/block_1_expand_BN/FusedBatchNormV3 action_count 207323 step 17194364464801385511 next 212
# 2021-07-25 14:23:24.439389: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at c04e06100 of size 2304 by op AssignVariableOp action_count 4677 step 0 next 213
# 2021-07-25 14:23:24.439652: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at c04e06a00 of size 1024 by op SameWorkerRecvDone action_count 206211 step 0 next 915
# 2021-07-25 14:23:24.439827: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at c04e06e00 of size 1280 by op SameWorkerRecvDone action_count 206213 step 0 next 215
# 2021-07-25 14:23:24.440058: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at c04e07300 of size 2304 by op AssignVariableOp action_count 4679 step 0 next 216
# 2021-07-25 14:23:24.440220: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at c04e07c00 of size 2304 by op while/body/_1/ssd_mobile_net_v2fpn_keras_feature_extractor/model/block_8_depthwise_BN/FusedBatchNormV3 action_count 207587 step 17194364464801385511 next 217
# 2021-07-25 14:23:24.440500: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at c04e08500 of size 2560 by op AssignVariableOp action_count 4697 step 0 next 199
# 2021-07-25 14:23:24.440660: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at c04e08f00 of size 20736 by op AssignVariableOp action_count 4675 step 0 next 200
# 2021-07-25 14:23:24.440882: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at c04e0e000 of size 512 by op while/body/_1/ssd_mobile_net_v2fpn_keras_feature_extractor/model/block_1_expand_BN/FusedBatchNormV3 action_count 207324 step 17194364464801385511 next 219
# 2021-07-25 14:23:24.441130: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at c04e0e200 of size 512 by op AssignVariableOp action_count 4689 step 0 next 220
# 2021-07-25 14:23:24.441297: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at c04e0e400 of size 3328 by op SameWorkerRecvDone action_count 206209 step 0 next 224
# 2021-07-25 14:23:24.441456: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at c04e0f100 of size 2304 by op AssignVariableOp action_count 4699 step 0 next 225
# 2021-07-25 14:23:24.441613: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at c04e0fa00 of size 2304 by op while/body/_1/ssd_mobile_net_v2fpn_keras_feature_extractor/model/block
I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at c04e3e400 of size 1024 by op while/body/_1/ssd_mobile_net_v2fpn_keras_feature_extractor/model/block_4_expand_BN/FusedBatchNormV3 action_count 207429 step 17194364464801385511 next 352
# 2021-07-25 14:23:24.447084: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at c04e3e800 of size 256 by op Sub action_count 712 step 0 next 353
# 2021-07-25 14:23:24.447248: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at c04e3e900 of size 256 by op Sub action_count 720 step 0 next 357
# 2021-07-25 14:23:24.447484: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at c04e3ea00 of size 256 by op Sub action_count 721 step 0 next 358
# 2021-07-25 14:23:24.447581: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at c04e3eb00 of size 256 by op Fill action_count 728 step 0 next 356
# 2021-07-25 14:23:24.447764: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at c04e3ec00 of size 256 by op Sub action_count 737 step 0 next 361
# 2021-07-25 14:23:24.447915: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at c04e3ed00 of size 256 by op Sub action_count 738 step 0 next 362
# Windows fatal exception: access violation
#
# Thread 0x00001100 (most recent call first):
#   File "C:\Program Files\Python38\lib\multiprocessing\pool.py", line 576 in _handle_results
#   File "C:\Program Files\Python38\lib\threading.py", line 870 in run
#   File "C:\Program Files\Python38\lib\threading.py", line 932 in _bootstrap_inner
#   File "C:\Program Files\Python38\lib\threading.py", line 890 in _bootstrap
#
# Thread 0x00004bb8 (most recent call first):
#   File "C:\Program Files\Python38\lib\multiprocessing\pool.py", line 528 in _handle_tasks
#   File "C:\Program Files\Python38\lib\threading.py", line 870 in run
#   File "C:\Program Files\Python38\lib\threading.py", line 932 in _bootstrap_inner
#   File "C:\Program Files\Python38\lib\threading.py", line 890 in _bootstrap
#
# Thread 0x000057e4 (most recent call first):
#   File "C:\Program Files\Python38\lib\multiprocessing\connection.py", line 810 in _exhaustive_wait
#   File "C:\Program Files\Python38\lib\multiprocessing\connection.py", line 878 in wait
#   File "C:\Program Files\Python38\lib\multiprocessing\pool.py", line 499 in _wait_for_updates
#   File "C:\Program Files\Python38\lib\multiprocessing\pool.py", line 519 in _handle_workers
#   File "C:\Program Files\Python38\lib\threading.py", line 870 in run
#   File "C:\Program Files\Python38\lib\threading.py", line 932 in _bootstrap_inner
#   File "C:\Program Files\Python38\lib\threading.py", line 890 in _bootstrap
#
# Thread 0x00001a98 (most recent call first):
#   File "C:\Program Files\Python38\lib\multiprocessing\pool.py", line 114 in worker
#   File "C:\Program Files\Python38\lib\threading.py", line 870 in run
#   File "C:\Program Files\Python38\lib\threading.py", line 932 in _bootstrap_inner
#   File "C:\Program Files\Python38\lib\threading.py", line 890 in _bootstrap
#
# Thread 0x00004c84 (most recent call first):
#   File "C:\TFOD\TFODCourse\tfod2\lib\site-packages\tensorflow\python\eager\execute.py", line 59 in quick_execute
#   File "C:\TFOD\TFODCourse\tfod2\lib\site-packages\tensorflow\python\eager\function.py", line 591 in call
#   File "C:\TFOD\TFODCourse\tfod2\lib\site-packages\tensorflow\python\eager\function.py", line 1960 in _call_flat
#   File "C:\TFOD\TFODCourse\tfod2\lib\site-packages\tensorflow\python\eager\function.py", line 3023 in __call__
#   File "C:\TFOD\TFODCourse\tfod2\lib\site-packages\tensorflow\python\eager\def_function.py", line 950 in _call
#   File "C:\TFOD\TFODCourse\tfod2\lib\site-packages\tensorflow\python\eager\def_function.py", line 889 in __call__
#   File "C:\TFOD\TFODCourse\tfod2\lib\site-packages\object_detection-0.1-py3.8.egg\object_detection\model_lib_v2.py", line 678 in train_loop
#   File "Tensorflow\models\research\object_detection\model_main_tf2.py", line 106 in main
#   File "C:\TFOD\TFODCourse\tfod2\lib\site-packages\absl\app.py", line 258 in _run_main
#   File "C:\TFOD\TFODCourse\tfod2\lib\site-packages\absl\app.py", line 312 in run
#   File "C:\TFOD\TFODCourse\tfod2\lib\site-packages\tensorflow\python\platform\app.py", line 40 in run
#   File "Tensorflow\models\research\object_detection\model_main_tf2.py", line 115 in <module>

# %% [markdown]
# # 7. Evaluate the Model

# %%
command = "python {} --model_dir={} --pipeline_config_path={} --checkpoint_dir={}".format(TRAINING_SCRIPT, paths['CHECKPOINT_PATH'],files['PIPELINE_CONFIG'], paths['CHECKPOINT_PATH'])

# %%
print(command)

# %%
# !{command}

# %% [markdown]
# # 8. Load Train Model From Checkpoint

# %%
import os
import tensorflow as tf
from object_detection.utils import label_map_util
from object_detection.utils import visualization_utils as viz_utils
from object_detection.builders import model_builder
from object_detection.utils import config_util

# %%
# Load pipeline config and build a detection model
configs = config_util.get_configs_from_pipeline_file(files['PIPELINE_CONFIG'])
detection_model = model_builder.build(model_config=configs['model'], is_training=False)

# Restore checkpoint
ckpt = tf.compat.v2.train.Checkpoint(model=detection_model)
ckpt.restore(os.path.join(paths['CHECKPOINT_PATH'], 'ckpt-5')).expect_partial()

@tf.function
def detect_fn(image):
    image, shapes = detection_model.preprocess(image)
    prediction_dict = detection_model.predict(image, shapes)
    detections = detection_model.postprocess(prediction_dict, shapes)
    return detections

# %% [markdown]
# # 9. Detect from an Image

# %%
import cv2 
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
category_index = label_map_util.create_category_index_from_labelmap(files['LABELMAP'])

# %%
paths['IMAGE_PATH']

# %%
IMAGE_PATH = os.path.join(paths['IMAGE_PATH'], 'test', '30.jpg')

# %%
num_detections

# %%
detections.keys()

# %%
detections['raw_detection_scores']

# %%
img = cv2.imread(IMAGE_PATH)
image_np = np.array(img)

input_tensor = tf.convert_to_tensor(np.expand_dims(image_np, 0), dtype=tf.float32)
detections = detect_fn(input_tensor)

num_detections = int(detections.pop('num_detections'))
detections = {key: value[0, :num_detections].numpy()
              for key, value in detections.items()}
detections['num_detections'] = num_detections

# detection_classes should be ints.
detections['detection_classes'] = detections['detection_classes'].astype(np.int64)

label_id_offset = 1
image_np_with_detections = image_np.copy()

viz_utils.visualize_boxes_and_labels_on_image_array(
            image_np_with_detections,
            detections['detection_boxes'],
            detections['detection_classes']+label_id_offset,
            detections['detection_scores'],
            category_index,
            use_normalized_coordinates=True,
            #max_boxes_to_draw=5,
            #min_score_thresh=.8,
            max_boxes_to_draw=20,
            min_score_thresh=.8,
            agnostic_mode=False)

plt.imshow(cv2.cvtColor(image_np_with_detections, cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# # 10. Real Time Detections from your Webcam

# %%
# !pip uninstall opencv-python-headless -y

# %%
cap = cv2.VideoCapture(0)
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

while cap.isOpened(): 
    ret, frame = cap.read()
    image_np = np.array(frame)
    
    input_tensor = tf.convert_to_tensor(np.expand_dims(image_np, 0), dtype=tf.float32)
    detections = detect_fn(input_tensor)
    
    num_detections = int(detections.pop('num_detections'))
    detections = {key: value[0, :num_detections].numpy()
                  for key, value in detections.items()}
    detections['num_detections'] = num_detections

    # detection_classes should be ints.
    detections['detection_classes'] = detections['detection_classes'].astype(np.int64)

    label_id_offset = 1
    image_np_with_detections = image_np.copy()

    viz_utils.visualize_boxes_and_labels_on_image_array(
                image_np_with_detections,
                detections['detection_boxes'],
                detections['detection_classes']+label_id_offset,
                detections['detection_scores'],
                category_index,
                use_normalized_coordinates=True,
                max_boxes_to_draw=5,
                min_score_thresh=.8,
                agnostic_mode=False)

    cv2.imshow('object detection',  cv2.resize(image_np_with_detections, (800, 600)))
    
    if cv2.waitKey(10) & 0xFF == ord('q'):
        cap.release()
        cv2.destroyAllWindows()
        break

# %% [markdown]
# # 10. Freezing the Graph

# %%
FREEZE_SCRIPT = os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection', 'exporter_main_v2.py ')

# %%
command = "python {} --input_type=image_tensor --pipeline_config_path={} --trained_checkpoint_dir={} --output_directory={}".format(FREEZE_SCRIPT ,files['PIPELINE_CONFIG'], paths['CHECKPOINT_PATH'], paths['OUTPUT_PATH'])

# %%
print(command)

# %%
# !{command}

# %% [markdown]
# # 11. Conversion to TFJS

# %%
# !pip install tensorflowjs

# %%
command = "tensorflowjs_converter --input_format=tf_saved_model --output_node_names='detection_boxes,detection_classes,detection_features,detection_multiclass_scores,detection_scores,num_detections,raw_detection_boxes,raw_detection_scores' --output_format=tfjs_graph_model --signature_name=serving_default {} {}".format(os.path.join(paths['OUTPUT_PATH'], 'saved_model'), paths['TFJS_PATH'])

# %%
print(command)

# %%
# !{command}

# %%
# Test Code: https://github.com/nicknochnack/RealTimeSignLanguageDetectionwithTFJS

# %% [markdown]
# # 12. Conversion to TFLite

# %%
TFLITE_SCRIPT = os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection', 'export_tflite_graph_tf2.py ')

# %%
command = "python {} --pipeline_config_path={} --trained_checkpoint_dir={} --output_directory={}".format(TFLITE_SCRIPT ,files['PIPELINE_CONFIG'], paths['CHECKPOINT_PATH'], paths['TFLITE_PATH'])

# %%
print(command)

# %%
# !{command}

# %%
FROZEN_TFLITE_PATH = os.path.join(paths['TFLITE_PATH'], 'saved_model')
TFLITE_MODEL = os.path.join(paths['TFLITE_PATH'], 'saved_model', 'detect.tflite')

# %%
command = "tflite_convert \
--saved_model_dir={} \
--output_file={} \
--input_shapes=1,300,300,3 \
--input_arrays=normalized_input_image_tensor \
--output_arrays='TFLite_Detection_PostProcess','TFLite_Detection_PostProcess:1','TFLite_Detection_PostProcess:2','TFLite_Detection_PostProcess:3' \
--inference_type=FLOAT \
--allow_custom_ops".format(FROZEN_TFLITE_PATH, TFLITE_MODEL, )

# %%
print(command)

# %%
# !{command}

# %% [markdown]
# # 13. Zip and Export Models

# %%
# !tar -czf models.tar.gz {paths['CHECKPOINT_PATH']}

# %%
from google.colab import drive
drive.mount('/content/drive')
